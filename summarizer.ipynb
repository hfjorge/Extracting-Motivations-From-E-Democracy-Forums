# %%
from langchain_community.graphs import Neo4jGraph
from langchain_ollama import ChatOllama
import re
from langchain_core.prompts import  PromptTemplate
import uuid
from dotenv import load_dotenv

load_dotenv(override = True)
# Out:
# True

# %%
graph = Neo4jGraph()

# %%
topic_title = 'Could U.S. involvement in Iran trigger a larger global war?'

# %%
original_post = graph.query(
    """
    MATCH (p:OriginalPost)
    WHERE p.topic_title = $topic_title
    RETURN p
    """,
    {'topic_title': topic_title}
)
original_post_id = original_post[0]['p']['id'] if original_post and 'p' in original_post[0] and 'id' in original_post[0]['p'] else None

# %%
argument_count_result = graph.query(
    """
    MATCH (a:Argument)--(p)
    WHERE (p:Post OR p:OriginalPost) AND p.topic_title = $topic_title
    RETURN count(DISTINCT a) AS total_arguments
    """,
    {'topic_title': topic_title}
)

total_arguments = argument_count_result[0]['total_arguments'] if argument_count_result else 0
print(f"Total arguments for topic: {total_arguments}")
# Out:
# Total arguments for topic: 23

# %%
results = graph.query(
    """
    MATCH (a:Argument)--(mn:MaxNeefCategory), (a)--(p)
    WHERE (p:Post OR p:OriginalPost) AND p.topic_title = $topic_title
    RETURN mn.id AS category, collect(DISTINCT a.motivations_descriptions) AS motivations, count(DISTINCT a) AS argument_count
    ORDER BY category
    """, 
    {'topic_title':topic_title}
)

# %%
MODEL = "deepseek-r1:8b"

summary_extractor = ChatOllama(
        model=MODEL,
        temperature=0,
        #format="json"
    )

summary_extraction_prompt = PromptTemplate(
    input_variables=["motivations"],
    template= """
    Your task is to process the following strands of text, containing the descriptions of various motivations, and summarize it.
    Make a sumarization of the most common themes and what was overall said. 
    You dont need to go too in depth, only enough to get the pig picture.
    The text comes from many users on the internet, on the context of a discussion forum. 
    Input:

    \"\"\"{motivations}\"\"\"
    """
    )
    
summary_chain = summary_extraction_prompt | summary_extractor

# %%
def remove_think_tags(text):
    return re.sub(r'<think>.*?</think>', '', text, flags=re.DOTALL)

# %%
def create_summary_node(new_id, description, n_arguments_used):
    # Ensures that the MotivationSummary node with this ID does not exist before creating it
    presence = n_arguments_used / total_arguments if total_arguments else 0

    graph.query(
        """
        MERGE (n:MotivationSummary {id: $id})
        ON CREATE SET n.description = $description,
                      n.n_arguments_analyzed = $n_arguments_analyzed,
                      n.n_arguments_used = $n_arguments_used,
                      n.presence = $presence
        ON MATCH SET n.description = $description,
                     n.n_arguments_analyzed = $n_arguments_analyzed,
                     n.n_arguments_used = $n_arguments_used,
                     n.presence = $presence
        """,
        {
            "id": new_id,
            "description": description,
            "n_arguments_analyzed": total_arguments,
            "n_arguments_used": n_arguments_used,
            "presence": presence
        }
    )

    return False


def create_summary_relations(new_id, category_id, post_id):
    # Creates a REFLECTS relationship only if it does not already exist
    graph.query(
        """
        MATCH (a:MotivationSummary {id: $novo_id}), (b:MaxNeefCategory {id: $categoria_id})
        MERGE (a)-[:REFLECTS]->(b)
        """,
        {"novo_id": new_id, "categoria_id": category_id}
    )

    # Creates a SUMMARIZES relationship only if it does not already exist
    graph.query(
        """
        MATCH (a:MotivationSummary {id: $novo_id}), (b:OriginalPost {id: $post_id})
        MERGE (a)-[:SUMMARIZES]->(b)
        """,
        {"novo_id": new_id, "post_id": post_id}
    )

    return False

# %%
for line in results:


    # Process text
    print("Category: ", line.get("category"))
    print("Motivations: ", line.get("motivations"))
    print("Arguments present: ", line.get("argument_count"))


    input = {
        #'category' : line.get("category"),
        'motivations' : line.get("motivations")
    }

    response = summary_chain.invoke(input).content
    description = remove_think_tags(response)


    # Create nodes
    id = str(uuid.uuid4())

    create_summary_node(new_id=id, description=description, n_arguments_used=line.get("argument_count"))


    # Create relationships

    create_summary_relations(new_id=id, category_id=line.get("category"), post_id=original_post_id)
# Out:
# Category:  Affection
# Motivations:  [['Wants to safeguard civilian lives and global stability by opposing military invasions.', 'Seeks to critically analyze and understand patterns of geopolitical aggression and leadership failures.', 'Values national sovereignty and self-determination, opposing violations of freedom by powerful states.', 'Expresses empathy for victims of war and conflict who suffer from aggressive military actions.']]
# Argumentos presentes:  1
# Category:  Creativity
# Motivations:  [['Wants readers to grasp how shifts in national power reshape global strategy and influence.', 'Advocates replacing nostalgic visions with innovative, forward-looking policies to stay relevant.', 'Seeks to motivate public and policy engagement by highlighting the contest over international leadership.']]
# Argumentos presentes:  1
# Category:  Freedom
# Motivations:  [['Wants to maintain regional stability and safety by preventing a nuclear arms race among neighboring countries.', "Seeks to preserve China's strategic autonomy and freedom of action by avoiding constraints imposed by neighboring nuclear powers.", 'Aims to foster cooperative and non-hostile relations with regional neighbors to ensure peaceful coexistence.'], ['Wants to safeguard civilian lives and global stability by opposing military invasions.', 'Seeks to critically analyze and understand patterns of geopolitical aggression and leadership failures.', 'Values national sovereignty and self-determination, opposing violations of freedom by powerful states.', 'Expresses empathy for victims of war and conflict who suffer from aggressive military actions.'], ['Emphasizes that patient, long-term planning based on relative growth data leads to more informed decision-making.', 'Highlights that by growing stronger before acting, China ensures its strategic security and stability.', 'Asserts that building strength over time preserves China’s future autonomy in geopolitical decisions.'], ['Wants to protect society from instability and harm caused by those seeking profit through repeating historical mistakes.', 'Opposes unfair exploitation that undermines others’ autonomy and well-being.', 'Advocates for critical and responsible use of historical knowledge to prevent repeating harmful cycles.']]
# Argumentos presentes:  4
# Category:  Identity
# Motivations:  [['Wants to prevent a loss of regime legitimacy and domestic stability by avoiding the image of an ‘incomplete’ nation on a major political milestone.', 'Aims to uphold national pride and cohesion by ensuring China appears territorially whole at its 100-year anniversary.'], ['Affirming national unity by emphasizing Taiwan as integral territory to reinforce a sense of belonging.', 'Using logical coherence to argue against invasion by pointing out one does not attack one’s own people.', 'Emphasizing stability and safety to discourage the prospect of internal military conflict.']]
# Argumentos presentes:  2
# Category:  Participation
# Motivations:  [['Stressing that without US-supplied bunker busters and equipment, Israel cannot secure its borders and neutralize threats.', 'Informing the audience about Israel’s technical limitations to underline the necessity of allied cooperation in military operations.'], ['Aims to inform readers about the structure and risks of global supply chains centered on Taiwan’s semiconductor industry.', 'Seeks to emphasize the need to safeguard semiconductor production to maintain economic stability worldwide.', 'Intends to motivate governments and businesses to engage in policies and partnerships supporting Taiwan’s chip manufacturing.'], ['Wants readers to grasp how shifts in national power reshape global strategy and influence.', 'Advocates replacing nostalgic visions with innovative, forward-looking policies to stay relevant.', 'Seeks to motivate public and policy engagement by highlighting the contest over international leadership.'], ['Wants to maintain regional stability and safety by preventing a nuclear arms race among neighboring countries.', "Seeks to preserve China's strategic autonomy and freedom of action by avoiding constraints imposed by neighboring nuclear powers.", 'Aims to foster cooperative and non-hostile relations with regional neighbors to ensure peaceful coexistence.'], ['Wants to ground the discussion in realistic military capabilities to avoid exaggeration and misinformation.', 'Aims to reduce public fear of imminent conflict by stressing the logistical challenges of an amphibious invasion.', 'Encourages informed debate on foreign policy by focusing on factual assessments rather than alarmist scenarios.'], ['Wants readers to critically reassess the simplistic assumption that the CCP will always act rationally.', 'Aims to warn about the security risks of underestimating how domestic pressures in China could lead to reckless actions.', 'Seeks to prompt policymakers and the public to actively consider internal Chinese factors when shaping foreign policy decisions.'], ['Belief that historical knowledge fosters critical thinking and informed decision-making.', 'Desire to prevent repeating past mistakes to ensure safety and stability.', 'Encouragement of societal responsibility to actively learn and apply lessons from history.'], ['Wants to highlight historical parallels to caution against repeating past policy mistakes.', 'Seeks to encourage critical evaluation of current government rhetoric about military action.', 'Aims to foster public vigilance and involvement in foreign policy discourse to prevent undue escalation.'], ['Warns about serious safety and stability risks from military intervention to protect lives and regional security.', 'Emphasizes the need for critical analysis of political decisions to understand and avoid repeating past mistakes.', 'Urges citizens to engage in political discourse and hold leaders accountable for foreign policy choices.'], ['Emphasizes our repeated failure to heed historical lessons to foster deeper critical reflection.', 'Expresses concern that ignoring history risks repeating past conflicts and societal harm.', 'Aims to spur public responsibility and engagement in learning from history to influence current decisions.']]
# Argumentos presentes:  10
# Category:  Protection
# Motivations:  [['Stressing that without US-supplied bunker busters and equipment, Israel cannot secure its borders and neutralize threats.', 'Informing the audience about Israel’s technical limitations to underline the necessity of allied cooperation in military operations.'], ['Aims to inform readers about the structure and risks of global supply chains centered on Taiwan’s semiconductor industry.', 'Seeks to emphasize the need to safeguard semiconductor production to maintain economic stability worldwide.', 'Intends to motivate governments and businesses to engage in policies and partnerships supporting Taiwan’s chip manufacturing.'], ['Seeks to prevent escalation into a wider conflict to preserve safety and stability.', 'Highlights the need for careful strategic assessment to inform decision-making.'], ['Wants to maintain regional stability and safety by preventing a nuclear arms race among neighboring countries.', "Seeks to preserve China's strategic autonomy and freedom of action by avoiding constraints imposed by neighboring nuclear powers.", 'Aims to foster cooperative and non-hostile relations with regional neighbors to ensure peaceful coexistence.'], ['Desires to reassure that rational actors will avoid conflict, promoting political stability and safety.', 'Uses historical examples and logical risk assessment to form an evidence-based argument, reflecting a need for critical understanding.', "Highlights potential destruction of Taiwan's semiconductor industry to underscore material and economic consequences, reflecting concern for subsistence needs."], ['Concern about preventing a destabilizing military confrontation until the balance of power is more even', 'Desire to apply rational analysis of military capabilities to understand and predict geopolitical developments'], ['Wants to safeguard civilian lives and global stability by opposing military invasions.', 'Seeks to critically analyze and understand patterns of geopolitical aggression and leadership failures.', 'Values national sovereignty and self-determination, opposing violations of freedom by powerful states.', 'Expresses empathy for victims of war and conflict who suffer from aggressive military actions.'], ['Emphasizes China’s incentive to maintain regional stability and security rather than risk aggression against Taiwan.', 'Offers a reasoned analysis of shifting global power balances to clarify China’s strategic choices.'], ['Emphasizes that patient, long-term planning based on relative growth data leads to more informed decision-making.', 'Highlights that by growing stronger before acting, China ensures its strategic security and stability.', 'Asserts that building strength over time preserves China’s future autonomy in geopolitical decisions.'], ['Wants to prevent a loss of regime legitimacy and domestic stability by avoiding the image of an ‘incomplete’ nation on a major political milestone.', 'Aims to uphold national pride and cohesion by ensuring China appears territorially whole at its 100-year anniversary.'], ['Prefers maintaining a peaceful but imperfect arrangement to avoid the risks and harms of actual conflict', 'Values a pragmatic compromise over ideological purity through critical assessment of less harmful options'], ['Wants to ground the discussion in realistic military capabilities to avoid exaggeration and misinformation.', 'Aims to reduce public fear of imminent conflict by stressing the logistical challenges of an amphibious invasion.', 'Encourages informed debate on foreign policy by focusing on factual assessments rather than alarmist scenarios.'], ['Emphasizes the high security and stability risks of an invasion by pointing out likely US military support for Taiwan, highlighting potential dangers and costs.', 'Offers a reasoned geopolitical analysis to inform readers about strategic consequences and encourage critical evaluation of the invasion scenario.'], ['Affirming national unity by emphasizing Taiwan as integral territory to rein ...
# Argumentos presentes:  22
# Category:  Subsistence
# Motivations:  [['Desires to reassure that rational actors will avoid conflict, promoting political stability and safety.', 'Uses historical examples and logical risk assessment to form an evidence-based argument, reflecting a need for critical understanding.', "Highlights potential destruction of Taiwan's semiconductor industry to underscore material and economic consequences, reflecting concern for subsistence needs."]]
# Argumentos presentes:  1
# Category:  Understanding
# Motivations:  [['Stressing that without US-supplied bunker busters and equipment, Israel cannot secure its borders and neutralize threats.', 'Informing the audience about Israel’s technical limitations to underline the necessity of allied cooperation in military operations.'], ['Aims to inform readers about the structure and risks of global supply chains centered on Taiwan’s semiconductor industry.', 'Seeks to emphasize the need to safeguard semiconductor production to maintain economic stability worldwide.', 'Intends to motivate governments and businesses to engage in policies and partnerships supporting Taiwan’s chip manufacturing.'], ['Seeks to prevent escalation into a wider conflict to preserve safety and stability.', 'Highlights the need for careful strategic assessment to inform decision-making.'], ['Wants readers to grasp how shifts in national power reshape global strategy and influence.', 'Advocates replacing nostalgic visions with innovative, forward-looking policies to stay relevant.', 'Seeks to motivate public and policy engagement by highlighting the contest over international leadership.'], ['Desires to reassure that rational actors will avoid conflict, promoting political stability and safety.', 'Uses historical examples and logical risk assessment to form an evidence-based argument, reflecting a need for critical understanding.', "Highlights potential destruction of Taiwan's semiconductor industry to underscore material and economic consequences, reflecting concern for subsistence needs."], ['Concern about preventing a destabilizing military confrontation until the balance of power is more even', 'Desire to apply rational analysis of military capabilities to understand and predict geopolitical developments'], ['Wants to safeguard civilian lives and global stability by opposing military invasions.', 'Seeks to critically analyze and understand patterns of geopolitical aggression and leadership failures.', 'Values national sovereignty and self-determination, opposing violations of freedom by powerful states.', 'Expresses empathy for victims of war and conflict who suffer from aggressive military actions.'], ['Emphasizes China’s incentive to maintain regional stability and security rather than risk aggression against Taiwan.', 'Offers a reasoned analysis of shifting global power balances to clarify China’s strategic choices.'], ['Emphasizes that patient, long-term planning based on relative growth data leads to more informed decision-making.', 'Highlights that by growing stronger before acting, China ensures its strategic security and stability.', 'Asserts that building strength over time preserves China’s future autonomy in geopolitical decisions.'], ['Prefers maintaining a peaceful but imperfect arrangement to avoid the risks and harms of actual conflict', 'Values a pragmatic compromise over ideological purity through critical assessment of less harmful options'], ['Wants to ground the discussion in realistic military capabilities to avoid exaggeration and misinformation.', 'Aims to reduce public fear of imminent conflict by stressing the logistical challenges of an amphibious invasion.', 'Encourages informed debate on foreign policy by focusing on factual assessments rather than alarmist scenarios.'], ['Emphasizes the high security and stability risks of an invasion by pointing out likely US military support for Taiwan, highlighting potential dangers and costs.', 'Offers a reasoned geopolitical analysis to inform readers about strategic consequences and encourage critical evaluation of the invasion scenario.'], ['Affirming national unity by emphasizing Taiwan as integral territory to reinforce a sense of belonging.', 'Using logical coherence to argue against invasion by pointing out one does not attack one’s own people.', 'Emphasizing stability and safety to discourage the prospect of internal military conflict.'], ['Wants readers to critically reassess the simplistic assumption that the CCP will always act rat ...
# Argumentos presentes:  21
